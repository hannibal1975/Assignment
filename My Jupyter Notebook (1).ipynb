# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# # Hannibal Kimani

# %% [markdown]
# My current occupation is based on health services but my desire is to work as data scientist

# %% [markdown]
# _iam interested in data science because it has been my desire and my goal to become data scientist, its a high job market with great work schedule_.

# %% [markdown]
# SUBSTRACTION

# %%
200-199
# Out:
# 1

# %% [markdown]
# 1. TABLE
#
#
# |ITEM# |ITEM             |Manchester |Edinburg |
# |------|-----------------|-----------|---------|
# | 1    |Block splitter   |0          |3        |
# | 2    |Extension leads  |6          |3        |
# | 3    |Extension Reel   |0          |4        |
#
#
#
#
#
#
#
#
#
#
#
# 2. Numbered list
#
#
# 1 Exel
# 2 Spss statistics
# 3 python
# 4 R
# 5 SPSS Modeler
# 6 Open scale
# 7 IBM Watson Studio
#
#
#
#
#
#
#
#
#
#
#
#
#
# 3. Code Highlighting
#
# <Code>
# mylist = ['DataGirl', 1, True]
# </
